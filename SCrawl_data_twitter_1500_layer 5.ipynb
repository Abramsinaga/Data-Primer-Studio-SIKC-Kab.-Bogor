# %% [markdown]
# # Crawl Data Twitter > 1500 Tweets
# The crawling process was done using Tweet-Harvest. Written by Helmi Satria on October 18th.

# %%
#@title Twitter Auth Token

twitter_auth_token = 'auth token twitter'

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# ...
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,070 kB]
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,456 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
# Crawl Data
cari_data = 'allinlayer5' #ganti ini sajaaAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
filename = f'{cari_data}.csv'
#keywordcompile= 'bogor (kab OR kabupaten) (Ekosistem OR kecerdasan OR ekosistem OR cerdas OR pemangku OR kepentingan OR inovasi OR daerah OR kreasi OR cerdas OR daya OR saing OR ekosistem OR kota OR kreatif OR pendidikan OR teknologi OR stakeholder OR smart city OR stakeholder OR kota cerdas OR pendidikan OR IT OR pelayanan OR publik OR ekosistem OR teknologi OR kreasi OR cerdas OR ekosistem OR kota OR kreatif OR ekosistem OR smart OR city OR stakeholder OR Kualitas OR OR OR ketersediaan OR SDM OR Sumber OR daya OR manusia OR pendidikan OR pelatihan OR bimbingan OR teknis OR literasi OR peran OR masyarakat OR sdm OR kualitas OR SDM OR usia OR produktif OR career OR center OR masyarakat OR cerdas OR smart OR people OR desa OR mengajar OR literasi OR literasi OR digital OR sosialisasi OR command OR center OR perguruan OR tinggi OR sdm OR handal OR sdm OR unggul OR kompetisi OR bogor OR cerdas OR tingkat OR pendidikan OR usia OR produktif OR angkatan OR kerja OR Ketersediaan OR inovasi OR teknologi OR Informasi OR digital OR inovasi OR inovasi OR digital OR teknologi OR TIK OR teknologi OR informasi OR komunikasi OR spbe OR sistem OR informasi OR digital OR layanan OR digital OR inovasi OR teknologi) lang:id until:2023-12-31'
search_keyword = 'bogor (kab OR kabupaten) (Ekosistem OR kecerdasan OR ekosistem OR cerdas OR pemangku OR kepentingan OR inovasi OR daerah OR kreasi OR cerdas OR daya OR saing OR ekosistem OR kota OR kreatif OR pendidikan OR teknologi OR stakeholder OR smart OR city OR stakeholder OR kota OR cerdas OR pendidikan OR IT OR pelayanan OR publik OR ekosistem OR teknologi OR kreasi OR cerdas OR ekosistem OR kota OR kreatif OR ekosistem OR smart OR city OR stakeholder OR Kualitas OR OR OR ketersediaan OR SDM OR Sumber OR daya OR manusia OR pendidikan OR pelatihan OR bimbingan OR teknis OR literasi OR peran OR masyarakat OR sdm OR kualitas OR SDM OR usia OR produktif OR career OR center OR masyarakat OR cerdas OR smart OR people OR desa OR mengajar OR literasi OR literasi OR digital OR sosialisasi OR command OR center OR perguruan OR tinggi OR sdm OR handal OR sdm OR unggul OR kompetisi OR bogor OR cerdas OR tingkat OR pendidikan OR usia OR produktif OR angkatan OR kerja OR Ketersediaan OR inovasi OR teknologi OR Informasi OR digital OR inovasi OR inovasi OR digital OR teknologi OR TIK OR teknologi OR informasi OR komunikasi OR spbe OR sistem OR informasi OR digital OR layanan OR digital OR inovasi OR teknologi) lang:id until:2023-12-31'#GANTI INIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
limit = 1500

# !npx --yes tweet-harvest@2.2.8 -o "{filename}" -s "{search_keyword}" -l {limit} --token {twitter_auth_token}
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# up to date, audited 4 packages in 762ms
#
# found 0 vulnerabilities
# Installing dependencies...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"/content/tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=";")

# Display the DataFrame
display(df)
# Out:
#                         created_at               id_str  \
# 0   Fri Jun 09 04:40:32 +0000 2023  1667028883550662656
# 1   Mon Apr 10 23:19:21 +0000 2023  1645567170527793152
# 2   Sat Nov 05 03:19:00 +0000 2022  1588732586251399168
# 3   Sat Aug 06 12:05:53 +0000 2022  1555887884863164416
# 4   Sat Aug 06 09:43:11 +0000 2022  1555851975199453184
# 5   Fri Aug 05 08:19:43 +0000 2022  1555468579507937280
# 6   Fri Jul 15 10:31:24 +0000 2022  1547891575409111045
# 7   Wed Mar 30 03:04:30 +0000 2022  1509003606779117568
# 8   Tue Nov 09 04:55:39 +0000 2021  1457934887701266433
# 9   Mon Oct 25 04:45:03 +0000 2021  1452496402894897159
# 10  Fri Oct 22 04:10:27 +0000 2021  1451400532174667779
# 11  Fri Oct 01 04:17:53 +0000 2021  1443792257002389505
# 12  Thu Sep 16 21:52:34 +0000 2021  1438621861017882638
# 13  Fri Sep 10 07:29:00 +0000 2021  1436230208600772613
# 14  Fri Sep 10 04:35:03 +0000 2021  1436186432599564288
# 15  Fri Sep 10 02:48:41 +0000 2021  1436159664983457818
# ...

# %%
import shutil
# Specify the destination folder
destination_folder = "/content/drive/MyDrive/"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=";")

# Copy the file to the destination folder
shutil.copy(file_path, destination_folder)
# Out:
# '/content/drive/MyDrive/layanan_digital.csv'

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 18.
